# %%
# Set number of threads to use
import os
nthreads = 12
os.environ["MKL_NUM_THREADS"] = str(nthreads)
os.environ["NUMEXPR_NUM_THREADS"] = str(nthreads)
os.environ["OMP_NUM_THREADS"] = str(nthreads)

import warnings
warnings.filterwarnings("ignore")

# %%
#not needed but next time add path to SCING src directory
import sys
sys.path.insert(1,'../src/')

# %%
from supercellHelpers import *
from buildGRNHelpers import *
from MergeNetworksHelpers import *

# %%
root_dir = '/u/project/xyang123/julianas/medial_septum_sct'
os.path.join(root_dir, 'Saves/AnnData/celltype_adata/Neuron.h5ad')
# Out:
# '/u/project/xyang123/medial_septum_sct/Saves/AnnData/celltype_adata/Neuron.h5ad'

# %%
celltype_adatas = os.listdir("/u/home/j/julianas/scratch/medial_septum_sct/Saves/AnnData/celltype_adata")
celltype_adatas
# Out:
# ['Endothelial.h5ad',
#  'Ependymal.h5ad',
#  'Myelinating Oligodendrocyte.h5ad',
#  'Neuron.h5ad',
#  'Intermediate Progenitor Cell.h5ad',
#  'Astrocyte.h5ad',
#  'Oligodendrocyte Progenitor Cell.h5ad',
#  'Microglia.h5ad']

# %%
i=7
currentcell = celltype_adatas[i]
currentcell
# Out:
# 'Microglia.h5ad'

# %%
adata = sc.read("/u/home/j/julianas/scratch/medial_septum_sct/Saves/AnnData/celltype_adata/" + currentcell)

# %%
samples = adata.obs['sampleName'].unique().tolist()
samples
# Out:
# ['XY-TriSeptum-1',
#  'XY-TriSeptum-10',
#  'XY-TriSeptum-11',
#  'XY-TriSeptum-12',
#  'XY-TriSeptum-13',
#  'XY-TriSeptum-14',
#  'XY-TriSeptum-15',
#  'XY-TriSeptum-16',
#  'XY-TriSeptum-17',
#  'XY-TriSeptum-18',
#  'XY-TriSeptum-19',
#  'XY-TriSeptum-2',
#  'XY-TriSeptum-20',
#  'XY-TriSeptum-21',
#  'XY-TriSeptum-22',
#  'XY-TriSeptum-23',
#  'XY-TriSeptum-24',
#  'XY-TriSeptum-3',
#  'XY-TriSeptum-4',
#  'XY-TriSeptum-5',
#  'XY-TriSeptum-6',
#  'XY-TriSeptum-7',
#  'XY-TriSeptum-8',
#  'XY-TriSeptum-9']

# %% [markdown]
# # Testing

# %%
adata_sub = adata[adata.obs.sampleName == samples[0]]

adata_sub_merged = supercell_pipeline(adata_sub,
                                         ngenes = 2000,
                                         npcs=20,
                                         ncell = 50,
                                         verbose = True)
# Out:
# preprocessing data...
# finding optimal resolution...
# There are  101  supercells
# merging cells...

# %%
newID = samples[0] + "_" + adata_sub_merged.obs_names
adata_sub_merged.obs_names = newID

# %%
for column in adata_sub.obs.columns: 
    metadata = adata_sub.obs[column].values[1]
    metadata_name = column
    adata_sub_merged.obs[metadata_name] = metadata

adata_sub_merged.obs
# Out:
#                         sampleName Genotype SexChrom Gonad cell_type  \
# XY-TriSeptum-1_0    XY-TriSeptum-1      XYM       XY  Male    Neuron
# XY-TriSeptum-1_1    XY-TriSeptum-1      XYM       XY  Male    Neuron
# XY-TriSeptum-1_2    XY-TriSeptum-1      XYM       XY  Male    Neuron
# XY-TriSeptum-1_3    XY-TriSeptum-1      XYM       XY  Male    Neuron
# XY-TriSeptum-1_4    XY-TriSeptum-1      XYM       XY  Male    Neuron
# ...                            ...      ...      ...   ...       ...
# XY-TriSeptum-1_494  XY-TriSeptum-1      XYM       XY  Male    Neuron
# XY-TriSeptum-1_495  XY-TriSeptum-1      XYM       XY  Male    Neuron
# XY-TriSeptum-1_496  XY-TriSeptum-1      XYM       XY  Male    Neuron
# XY-TriSeptum-1_497  XY-TriSeptum-1      XYM       XY  Male    Neuron
# XY-TriSeptum-1_498  XY-TriSeptum-1      XYM       XY  Male    Neuron
#
#                         Trisomy
# XY-TriSeptum-1_0    Non-Trisomy
# XY-TriSeptum-1_1    Non-Trisomy
# XY-TriSeptum-1_2    Non-Trisomy
# XY-TriSeptum-1_3    Non-Trisomy
# XY-TriSeptum-1_4    Non-Trisomy
# ...                         ...
# XY-TriSeptum-1_494  Non-Trisomy
# XY-TriSeptum-1_495  Non-Trisomy
# XY-TriSeptum-1_496  Non-Trisomy
# XY-TriSeptum-1_497  Non-Trisomy
# XY-TriSeptum-1_498  Non-Trisomy
#
# [499 rows x 6 columns]

# %% [markdown]
# # Sample-specific Supercell Creation

# %%
adata_list = []

for i in range(0,24): 
    
    sample = samples[i]
    
    adata_sub = adata[adata.obs.sampleName == sample]    
    adata_sub_merged = supercell_pipeline(adata_sub,
                                         ngenes = 2000,
                                         npcs=20,
                                         ncell = 50,
                                         verbose = True)
    
    newID = sample + "_" + adata_sub_merged.obs_names
    adata_sub_merged.obs_names = newID
    
    for column in adata_sub.obs.columns: 
        metadata = adata_sub.obs[column].values[1]
        metadata_name = column
        adata_sub_merged.obs[metadata_name] = metadata
    
    adata_list.append(adata_sub_merged)
# Out:
# preprocessing data...
# finding optimal resolution...
# There are  49  supercells
# merging cells...
# preprocessing data...
# finding optimal resolution...
# There are  51  supercells
# merging cells...
# preprocessing data...
# finding optimal resolution...
# There are  51  supercells
# merging cells...
# preprocessing data...
# finding optimal resolution...
# There are  50  supercells
# merging cells...
# preprocessing data...
# finding optimal resolution...
# There are  49  supercells
# merging cells...
# preprocessing data...
# finding optimal resolution...
# There are  50  supercells
# merging cells...
# preprocessing data...
# finding optimal resolution...
# There are  48  supercells
# merging cells...
# preprocessing data...
# finding optimal resolution...
# There are  49  supercells
# merging cells...
# preprocessing data...
# finding optimal resolution...
# There are  49  supercells
# merging cells...
# preprocessing data...
# finding optimal resolution...
# There are  50  supercells
# merging cells...
# preprocessing data...
# finding optimal resolution...
# There are  51  supercells
# merging cells...
# preprocessing data...
# finding optimal resolution...
# There are  51  supercells
# merging cells...
# preprocessing data...
# finding optimal resolution...
# There are  48  supercells
# merging cells...
# preprocessing data...
# finding optimal resolution...
# There are  49  supercells
# merging cells...
# preprocessing data...
# finding optimal resolution...
# There are  48  supercells
# merging cells...
# preprocessing data...
# finding optimal resolution...
# There are  50  supercells
# merging cells...
# preprocessing data...
# finding optimal resolution...
# There are  49  supercells
# merging cells...
# preprocessing data...
# finding optimal resolution...
# There are  52  supercells
# merging cells...
# preprocessing data...
# finding optimal resolution...
# There are  51  supercells
# merging cells...
# preprocessing data...
# finding optimal resolution...
# There are  47  supercells
# merging cells...
# preprocessing data...
# finding optimal resolution...
# There are  37  supercells
# merging cells...
# preprocessing data...
# finding optimal resolution...
# There are  52  supercells
# merging cells...
# preprocessing data...
# finding optimal resolution...
# There are  50  supercells
# merging cells...
# preprocessing data...
# finding optimal resolution...
# There are  50  supercells
# merging cells...

# %%
adata_merged = adata_list[0].concatenate(adata_list[1:24])

# %%
adata_merged.var
# Out:
#             vst.mean  vst.variance  vst.variance.expected  \
# Xkr4        4.773830     32.674836              29.567566
# Gm1992      0.220463      0.312983               0.282036
# Gm19938     0.186868      0.231000               0.234014
# Gm37381     0.000545      0.000690               0.000572
# Rp1         0.004932      0.008018               0.005510
# ...              ...           ...                    ...
# AC124606.1  0.000000      0.000000               0.000000
# AC133095.2  0.000000      0.000000               0.000000
# AC133095.1  0.000000      0.000000               0.000000
# AC234645.1  0.000000      0.000000               0.000000
# AC149090.1  0.925627      1.819066               1.791613
#
#             vst.variance.standardized  vst.variable  highly_variable-0  \
# Xkr4                         1.105091             0               True
# Gm1992                       1.109728             0              False
# Gm19938                      0.987122             0              False
# Gm37381                      1.205280             0              False
# Rp1                          1.455052             1              False
# ...                               ...           ...                ...
# AC124606.1                   0.000000             0              False
# AC133095.2                   0.000000             0              False
# AC133095.1                   0.000000             0              False
# AC234645.1                   0.000000             0              False
# AC149090.1                   1.015323             0              False
#
#                  means-0  dispersions-0  dispersions_norm-0  \
# Xkr4        5.302901e-01       1.721945            0.932049
# Gm1992      1.000000e-12            NaN                 NaN
# Gm19938     1.000000e-12            NaN                 NaN
# Gm37381     1.000000e-12            NaN                 NaN
# Rp1         4.767543e-01       1.586517            0.396766
# ...                  ...            ...                 ...
# AC124606.1  1.000000e-12            NaN                 NaN
# AC133095.2  1.000000e-12            NaN                 NaN
# AC133095.1  1.000000e-12            NaN                 NaN
# AC234645.1  1.000000e-12            NaN                 NaN
# AC149090.1  4.362028e-01       1.475810           -0.040806
#
#             highly_variable-1  ...  dispersions-7  dispersions_norm-7  \
# Xkr4                    False  ...       1.925632            2.215897
# Gm1992                  False  ...            NaN                 NaN
# Gm19938                 False  ...            NaN                 NaN
# Gm37381                 False  ...            NaN                 NaN
# Rp1                     False  ...       1.425874            0.747028
# ...                       ...  ...            ...                 ...
# AC124606.1              False  ...            NaN                 NaN
# AC133095.2              False  ...            NaN                 NaN
# AC133095.1              False  ...            NaN                 NaN
# AC234645.1              False  ...            NaN                 NaN
# AC149090.1               True  ...       0.890678           -0.880006
#
#             highly_variable-8       means-8  dispersions-8  \
# Xkr4                    False  1.141928e+00       0.713301
# Gm1992                  False  1.000000e-12            NaN
# Gm19938                 False  1.059602e-01       0.297552
# Gm37381                 False  6.353933e-02       0.494717
# Rp1                     False  5.269656e-01       0.924501
# ...                       ...           ...            ...
# AC124606.1              False  1.000000e-12            NaN
# AC133095.2              False  1.000000e-12            NaN
# AC133095.1              False  1.000000e-12            NaN
# AC234645.1              False  1.000000e-12            NaN
# AC149090.1              False  1.054836e+00       0.754982
#
#             dispersions_norm-8  highly_variable-9       means-9  \
# Xkr4                 -0.136255               True  4.783344e-01
# Gm1992                     NaN              False  4.388188e-02
# Gm19938              -1.363565              False  4.807262e-02
# Gm37381              -0.670949              False  1.905980e-01
# Rp1                  -0.173849               True  3.793651e-01
# ...                        ...                ...           ...
# AC124606.1                 NaN              False  1.000000e-12
# AC133095.2                 NaN              False  1.000000e-12
# AC133095.1                 NaN              False  1.000000e-12
# AC234645.1                 NaN              False  1.000000e-12
# AC149090.1           -0.209172              False  9.638908e-01
#
#             dispersions-9  dispersions_norm-9
# Xkr4             1.837335            3.017545
# Gm1992           1.239573            0.669252
# Gm19938          1.332896            0.890679
# Gm37381          1.430863            0.760613
# Rp1              1.616041            1.624924
# ...                   ...                 ...
# AC124606.1            NaN                 NaN
# AC133095.2            NaN                 NaN
# AC133095.1            NaN                 NaN
# AC234645.1            NaN                 NaN
# AC149090.1       1.194812            0.472221
#
# [32285 rows x 101 columns]

# %%
#adata_merged.obs['sampleName'].unique().tolist()
adata_merged.var = adata_merged.var.iloc[:, 0:5]

# %%
adata.var
# Out:
#             vst.mean  vst.variance  vst.variance.expected  \
# Xkr4        4.773830     32.674836              29.567566
# Gm1992      0.220463      0.312983               0.282036
# Gm19938     0.186868      0.231000               0.234014
# Gm37381     0.000545      0.000690               0.000572
# Rp1         0.004932      0.008018               0.005510
# ...              ...           ...                    ...
# AC124606.1  0.000000      0.000000               0.000000
# AC133095.2  0.000000      0.000000               0.000000
# AC133095.1  0.000000      0.000000               0.000000
# AC234645.1  0.000000      0.000000               0.000000
# AC149090.1  0.925627      1.819066               1.791613
#
#             vst.variance.standardized  vst.variable
# Xkr4                         1.105091             0
# Gm1992                       1.109728             0
# Gm19938                      0.987122             0
# Gm37381                      1.205280             0
# Rp1                          1.455052             1
# ...                               ...           ...
# AC124606.1                   0.000000             0
# AC133095.2                   0.000000             0
# AC133095.1                   0.000000             0
# AC234645.1                   0.000000             0
# AC149090.1                   1.015323             0
#
# [32285 rows x 5 columns]

# %%
adata_merged.var
# Out:
#             vst.mean  vst.variance  vst.variance.expected  \
# Xkr4        4.773830     32.674836              29.567566
# Gm1992      0.220463      0.312983               0.282036
# Gm19938     0.186868      0.231000               0.234014
# Gm37381     0.000545      0.000690               0.000572
# Rp1         0.004932      0.008018               0.005510
# ...              ...           ...                    ...
# AC124606.1  0.000000      0.000000               0.000000
# AC133095.2  0.000000      0.000000               0.000000
# AC133095.1  0.000000      0.000000               0.000000
# AC234645.1  0.000000      0.000000               0.000000
# AC149090.1  0.925627      1.819066               1.791613
#
#             vst.variance.standardized  vst.variable
# Xkr4                         1.105091             0
# Gm1992                       1.109728             0
# Gm19938                      0.987122             0
# Gm37381                      1.205280             0
# Rp1                          1.455052             1
# ...                               ...           ...
# AC124606.1                   0.000000             0
# AC133095.2                   0.000000             0
# AC133095.1                   0.000000             0
# AC234645.1                   0.000000             0
# AC149090.1                   1.015323             0
#
# [32285 rows x 5 columns]

# %%
adata_merged.write_h5ad("/u/home/j/julianas/scratch/medial_septum_sct/Saves/AnnData/celltype_supercells_adata/50sc_" + currentcell)

# %%
def adata_merge(adata, sample, filename):
    adata_sub = adata[adata.obs.sampleName == sample]
    adata_sub_merged = supercell_pipeline(adata_sub,
                                         ngenes = 2000,
                                         npcs=20,
                                         ncell = 500,
                                         verbose = True)
    
    newID = samples[0] + "_" + adata_sub_merged.obs_names
    adata_sub_merged.obs_names = newID
    for column in adata_sub.obs.columns: 
        metadata = adata_sub.obs[column].values[1]
        adata_sub_merged.obs[metadata] = metadata

# %% [markdown]
# # Original Workflow

# %%
adata_merged = supercell_pipeline(adata,
                                  ngenes=2000,
                                  npcs=20,
                                  ncell=500,
                                  verbose=True)
# Out:
# preprocessing data...
# finding optimal resolution...
# There are  494  supercells
# merging cells...

# %%
adata_merged.obs_names #supercells
adata_merged.var_names #genes
# Out:
# Index(['Xkr4', 'Gm1992', 'Gm19938', 'Gm37381', 'Rp1', 'Sox17', 'Gm37587',
#        'Gm37323', 'Mrpl15', 'Lypla1',
#        ...
#        'Gm16367', 'AC163611.1', 'AC163611.2', 'AC140365.1', 'AC124606.2',
#        'AC124606.1', 'AC133095.2', 'AC133095.1', 'AC234645.1', 'AC149090.1'],
#       dtype='object', length=32285)

# %%
adata_merged.write_h5ad("/u/home/j/julianas/scratch/medial_septum_sct/Saves/AnnData/celltype_supercells_adata/Neuron.h5ad")

# %% [markdown]
# # SCING pipeline

# %%
# limit genes to 2000 random genes
# this is to speed up computation for the example
np.random.seed(0)
adata_merged = adata_merged[:,np.random.choice(np.arange(adata_merged.shape[1]),
                                       2000,
                                       replace=False)]

# %%
all_edges = []
for i in range(10):
    print(i)
    adata_saved = adata_merged.copy()
    
    # -1 all genes
    # 100 neighbors for each gene
    # 10 pcs
    # 0.7 subsample per run
    scing = grnBuilder(adata_merged, -1, 100, 10,0.7,
                      'test','test',12,int(2e9),True)
    scing.subsample_cells()

    scing.filter_genes()
    scing.filter_gene_connectivities()
    scing.build_grn()
    
    all_edges.append(scing.edges)
# Out:
# 0
# building local cluster
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Loading data into memory...
# Building dask graph...
# Computing dask graph...
# Closing client...
# 1
# building local cluster
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Loading data into memory...
# Building dask graph...
# Computing dask graph...
# Closing client...
# 2
# building local cluster
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Loading data into memory...
# Building dask graph...
# Computing dask graph...
# Closing client...
# 3
# building local cluster
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Loading data into memory...
# Building dask graph...
# Computing dask graph...
# Closing client...
# 4
# building local cluster
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Loading data into memory...
# Building dask graph...
# Computing dask graph...
# Closing client...
# 5
# building local cluster
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Loading data into memory...
# Building dask graph...
# Computing dask graph...
# Closing client...
# 6
# building local cluster
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Loading data into memory...
# Building dask graph...
# Computing dask graph...
# Closing client...
# 7
# building local cluster
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Loading data into memory...
# Building dask graph...
# Computing dask graph...
# Closing client...
# 8
# building local cluster
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Loading data into memory...
# Building dask graph...
# Computing dask graph...
# Closing client...
# 9
# building local cluster
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Loading data into memory...
# Building dask graph...
# Computing dask graph...
# Closing client...

# %%
import pickle as pkl
with open('../temp_data/edge.pkl','wb') as f:
    pkl.dump(all_edges, f)
    #all_edges = pkl.load(f)

# %%
merger = NetworkMerger(adata_merged,
                    all_edges,
                       0.2,
                    'test',
                    'test',
                    12,
                    int(2e9),
                    True)

# %%
merger.preprocess_network_files()
merger.remove_reversed_edges()
merger.remove_cycles()
merger.get_triads()
merger.remove_redundant_edges()
# Out:
# Preprocessing in network files...
# Summarizing networks...
# Removing bidirectional edges...
# Removing cycles...
# Getting triads to remove redundant edges...
# Removing redundant edges...
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Creating client...
# Loading data...
# Building dask graph...
# Closing client...
# Removing edges...

# %%
merger.edge_df.sort_values(by='importance',
                          ascending=False)
# Out:
#           source  target  importance
# 202   AC091551.1  MAGEF1  308.756290
# 68          ADI1    TFAM  244.651772
# 831   AL845472.1  ZNF649  225.824339
# 242        RPL32   RPL23  214.534835
# 1223  AC073861.1   RPL32  212.556117
# ...          ...     ...         ...
# 2943        SAFB   USP10   11.271596
# 9157       PPTC7    VTA1   11.206106
# 1365       CDAN1    EDF1   11.174349
# 4415      KLHL28    BIN3   11.151834
# 3592      ABCB10  PIWIL4   10.961789
#
# [11457 rows x 3 columns]

# %%
all_edges
# Out:
# [      importance   source      target
#  0   5.171499e+01  EEF1DP2  AL021368.2
#  0   4.195934e+01    WDR46        ASB8
#  0   4.185096e+01  METTL13      MRPL58
#  0   3.969062e+01   RANBP1  AC145285.4
#  0   3.949167e+01   ZNHIT3     ZSCAN32
#  ..           ...      ...         ...
#  50  1.093876e-16    TPGS2     TMEM154
#  47  1.062454e-16    SURF6    PPP1R15B
#  56  4.507718e-17    KYAT3        ICE1
#  70  4.286149e-17     MECR       CPSF4
#  51  3.624558e-17     PLAA       PPM1A
#
#  [138161 rows x 3 columns],
#        importance      source      target
#  0   7.662322e+01  AC091551.1      MAGEF1
#  0   5.127531e+01  AL122035.1  AC009318.1
#  0   4.855717e+01        MAF1      FRG1CP
#  0   4.414817e+01        LHPP        TCHP
#  0   4.120420e+01      MAGEF1      CCDC65
#  ..           ...         ...         ...
#  59  1.868499e-16       HACD3       MED24
#  83  1.701455e-16      ANKFY1      PHYKPL
#  60  1.549373e-16      TUBA1A    MIR503HG
#  68  3.416069e-17       NUTF2       HYOU1
#  99 -1.128891e-14  AL137145.1   LINC00539
#
#  [138594 rows x 3 columns],
#        importance      source      target
#  0   4.821189e+01  AC010149.1       MAK16
#  0   4.555164e+01       ECHS1      KCTD21
#  0   4.535481e+01     SLC35E4      FBXO45
#  0   4.319148e+01      MAGEF1  AC091551.1
#  0   4.263109e+01      ZNF200      ADCY10
#  ..           ...         ...         ...
#  64  1.149706e-16    KIAA1109        CD53
#  59  1.070889e-16      ZNF761        CCL3
#  53  3.804434e-17  GPRC5D-AS1        EML2
#  99 -3.166541e-15         SRI       VTI1B
#  99 -6.714792e-14       AIFM1      SETD1A
#
#  [138830 rows x 3 columns],
#        importance      source      target
#  0   5.086834e+01     L3HYPDH  AC010149.1
#  0   4.396431e+01  AC068446.1        FZD2
#  0   4.349274e+01       REXO4        HIRA
#  0   4.183287e+01       MOCS2       TBRG4
#  0   4.017913e+01      MAGEF1  AC091551.1
#  ..           ...         ...         ...
#  65  4.457857e-17     C1orf43        CALR
#  80  3.958512e-17        USP4       ATG4C
#  55  3.007527e-17        TPT1      RAB11A
#  55  2.273783e-17      NMRAL1      MBOAT2
#  99 -5.504969e-14    ADAMTSL4       PRDX4
#
#  [137219 rows x 3 columns],
#        importance   source      target
#  0   5.832733e+01    RCAN3      DUSP11
#  0   4.826591e+01  EEF1DP2  AL021368.2
#  0   4.117868e+01    ECHS1      PHLDB1
#  0   3.949265e+01   SPINT2       SPIN3
#  0   3.882174e+01   ZNF761        IQCE
#  ..           ...      ...         ...
#  52  1.938049e-16  DENND6A      ZNF654
#  69  1.923803e-16    STAC3        VBP1
#  56  1.902847e-16   RNF121       IMPA2
#  81  1.238787e-16    RPL23       TPCN2
#  75  6.495464e-17    QSOX2       HYOU1
#
#  [139271 rows x 3 columns],
#        importance      source      target
#  0   4.721491e+01       PSMB2      MAGEF1
#  0   4.712253e+01       KCTD1      DUSP11
#  0   4.441883e+01  AC124319.2     FAM173A
#  0   4.252532e+01        CYCS       BCAS2
#  0   4.119166e+01        DAG1       DYRK4
#  ..           ...         ...         ...
#  53  1.236639e-16       PPM1A        STX5
#  97  9.033724e-17     FAM214A      ANXA11
#  98  8.251411e-17   RAD51-AS1      TMEM71
#  64  7.433204e-17      PWWP2A      CLSTN1
#  69  9.175040e-18      ZNF782  AC011586.2
#
#  [138916 rows x 3 columns],
#        importance      source      target
#  0   6.086145e+01        ADI1        TFAM
#  0   5.553955e+01       KCTD1      DUSP11
#  0   4.957770e+01       COPZ1  AL021368.2
#  0   4.903304e+01     ZSCAN32      KCTD21
#  0   4.663288e+01  AC091551.1      MAGEF1
#  ..           ...         ...         ...
#  52  1.298926e-16       WDR13      CYB5D2
#  70  1.255053e-16      NUCKS1      PIK3C3
#  57  1.201378e-16       PRKCI        ACPP
#  66  4.489330e-17        CHFR      SEC22A
#  99 -1.378360e-13  AC012358.3      RNF215
#
#  [136473 rows x 3 columns],
#        importance      source      target
#  0   5.600050e+01       COPZ1  AL021368.2
#  0   4.567241e+01        TFAM       ACAT2
#  0   4.131342e+01        ADI1        TFAM
#  0   4.116031e+01  AL021368.2       COPZ1
#  0   4.045975e+01      CCDC47        EMC8
#  ..           ...         ...         ...
#  58  8.753625e-17       CCDC6      PPP1R2
#  73  8.207028e-17        PBX2      CYB5D2
#  64  3.149384e-17        PFN1      DNAJB1
#  99 -1.318719e-15     RPS6KB2      RAB40B
#  99 -1.217335e-13       CASP9       TOR1B
#
#  [139097 rows x 3 columns],
#        importance      source      target
#  0   5.226040e+01        ADI1        TFAM
#  0   4.404608e+01  AC019163.1  AC123768.3
#  0   4.330545e+01       STAC3      MRPS30
#  0   3.739182e+01       KCTD1      DUSP11
#  0   3.647923e+01      LRRC47       COPZ1
#  ..           ...         ...         ...
#  84  1.637177e-16       SART3        TMX1
#  57  1.630340e-16       GNPTG  AC092535.3
#  54  1.466887e-16       PIPOX      SEMA4C
#  79  1.056172e-16      MAP2K5      SMURF1
#  99 -7.711543e-14      TRMT44       TRAF2
#
#  [139452 rows x 3 columns],
#        importance      source      target
#  0   6.970871e+01       COPZ1  AL021368.2
#  0   6.067634e+01       PDE12       MAK16
#  0   5.374199e+01  AC091551.1      MAGEF1
#  0   5.102902e+01  AL845472.1      ZNF649
#  0   4.154708e+01        IER5        BAG3
#  ..           ...         ...         ...
#  57  2.256853e-16      GTF3C5        TLR3
#  50  1.589138e-16      SDHAP1        EMC2
#  61  1.525532e-16      MAP4K2    PPP1R12C
#  70  1.369846e-16      ZNF148       PHF20
#  99 -7.031136e-14  AC064807.1       PPIL3
#
#  [138660 rows x 3 columns]]
