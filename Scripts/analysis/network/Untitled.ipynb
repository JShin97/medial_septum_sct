# %%
import os
import warnings
import scanpy as sc
import numpy as np

# %%
from scing import supercells, build, merge
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 from scing import supercells, build, merge
#
# ModuleNotFoundError: No module named 'scing'

# %%
# Set number of threads to use
nthreads = 12
os.environ["MKL_NUM_THREADS"] = str(nthreads)
os.environ["NUMEXPR_NUM_THREADS"] = str(nthreads)
os.environ["OMP_NUM_THREADS"] = str(nthreads)
# filter warnings
warnings.filterwarnings("ignore")

# %%
adata = sc.read_h5ad('/u/scratch/j/jshin/medial_septum_sct/Saves/network/SCING/data/microglia.h5ad')
